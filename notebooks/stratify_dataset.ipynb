# %%
import numpy as np
import pandas as pd
import random
from collections import Counter

# %%
def dataframe_to_array(dataset):
    A = []
    counter = Counter()
    for idx, x in dataset.iterrows():
        fname = x.fname
        labels = x.labels.split(',')
        A.append([fname, labels])
    return A

# %%
def get_labels_counter(dataset):
    counter = Counter()
    for fname, labels in dataset:
        counter.update(labels)
    
    return counter

# %%
dataset = pd.read_csv('../input/train_curated.csv')
dataset = dataframe_to_array(dataset)

# %%
def check_input(k, arr):
    if(arr == None):
        arr = [1.0/k for i in range(k)]
    arr = np.array(arr)
    assert len(arr) == k
    assert arr.sum() == 1.0
    return arr

# %%
def stratify_multilabel(dataset, k, dist=None):
    dataset = dataset[:]
    # dist - distribution
    labels_counter = get_labels_counter(dataset)
    dist = check_input(k, dist)
    S = [[] for i in range(k)]
    C2 = []
    for j in range(k):
        temp = {label: int(labels_counter[label] * dist[j]) for label in labels_counter}
        C2.append(temp)
        
    while len(dataset) > 0:
        labels_left = get_labels_counter(dataset)
        l = min(labels_left, key=labels_left.get)
        to_delete = []
        for idx, x in enumerate(dataset):
            labels = x[1]
            if l not in labels:
                continue

            indexes = [C2[i][l] for i in range(k)]
            idx_max = np.argmax(indexes)
            fname = dataset[idx][0]
            labels = dataset[idx][1]
            for label in labels:
                C2[idx_max][label] -= 1
            S[idx_max].append(x)
            to_delete.append(idx)
        
        for e in sorted(to_delete, reverse=True):
            del dataset[e]
    return S

# %%
k = 3
S = stratify_multilabel(dataset, k, [0.8, 0.1, 0.1])

for num, s in enumerate(S):
    counter = get_labels_counter(s)
    print(num, ':!!!')
    for x, val in counter.items():
        print(x, ': ', val)
    print()
# Out:
# 0 :!!!
# Accordion :  38
# Gasp :  39
# Crowd :  61
# Mechanical_fan :  40
# Fill_(with_liquid) :  40
# Sink_(filling_or_washing) :  61
# Water_tap_and_faucet :  61
# Bathtub_(filling_or_washing) :  61
# Trickle_and_dribble :  43
# Drip :  61
# Squeak :  61
# Dishes_and_pots_and_pans :  61
# Gurgling :  61
# Stream :  61
# Buzz :  45
# Cricket :  61
# Bark :  61
# Chirp_and_tweet :  61
# Race_car_and_auto_racing :  45
# Accelerating_and_revving_and_vroom :  61
# Car_passing_by :  61
# Motorcycle :  61
# Glockenspiel :  45
# Sigh :  46
# Frying_(food) :  51
# Crackle :  61
# Traffic_noise_and_roadway_noise :  61
# Sneeze :  51
# Cutlery_and_silverware :  61
# Raindrop :  61
# Toilet_flush :  61
# Chink_and_clink :  61
# Purr :  53
# Meow :  61
# Clapping :  61
# Hiss :  61
# Bicycle_bell :  54
# Cheering :  61
# Applause :  61
# Yell :  61
# Bus :  61
# Screaming :  61
# Child_speech_and_kid_speaking :  61
# Harmonica :  61
# Tap :  61
# Knock :  61
# Cupboard_open_or_close :  61
# Drawer_open_or_close :  61
# Shatter :  61
# Bass_drum :  61
# Acoustic_guitar :  60
# Fart :  61
# Church_bell :  61
# Walk_and_footsteps :  61
# Writing :  61
# Electric_guitar :  61
# Slam :  61
# Microwave_oven :  61
# Run :  61
# Male_speech_and_man_speaking :  61
# Female_speech_and_woman_speaking :  61
# Waves_and_surf :  61
# Strum :  61
# Bass_guitar :  61
# Hi-hat :  61
# Whispering :  61
# Male_singing :  61
# Tick-tock :  58
# Female_singing :  61
# Finger_snapping :  61
# Chewing_and_mastication :  61
# Burping_and_eructation :  61
# Zipper_(clothing) :  61
# Marimba_and_xylophone :  61
# Keys_jangling :  61
# Skateboard :  61
# Computer_keyboard :  61
# Printer :  61
# Gong :  61
# Scissors :  61
#
# 1 :!!!
# Accordion :  5
# Gasp :  5
# Crowd :  7
# Mechanical_fan :  5
# Fill_(with_liquid) :  5
# Sink_(filling_or_washing) :  7
# Water_tap_and_faucet :  7
# Raindrop :  7
# Drip :  7
# Trickle_and_dribble :  5
# Buzz :  6
# Cricket :  7
# Race_car_and_auto_racing :  6
# Accelerating_and_revving_and_vroom :  7
# Motorcycle :  7
# Car_passing_by :  7
# Glockenspiel :  6
# Sigh :  6
# Frying_(food) :  6
# Sneeze :  6
# Gurgling :  7
# Toilet_flush :  7
# Bathtub_(filling_or_washing) :  7
# Child_speech_and_kid_speaking :  7
# Meow :  7
# Purr :  6
# Bicycle_bell :  7
# Applause :  7
# Cheering :  7
# Clapping :  7
# Harmonica :  7
# Cutlery_and_silverware :  7
# Dishes_and_pots_and_pans :  7
# Chink_and_clink :  7
# Tap :  7
# Shatter :  7
# Drawer_open_or_close :  7
# Traffic_noise_and_roadway_noise :  7
# Squeak :  7
# Slam :  7
# Walk_and_footsteps :  7
# Cupboard_open_or_close :  7
# Electric_guitar :  7
# Run :  7
# Microwave_oven :  7
# Knock :  7
# Chirp_and_tweet :  7
# Bark :  7
# Stream :  7
# Bus :  7
# Waves_and_surf :  7
# Bass_guitar :  7
# Acoustic_guitar :  8
# Strum :  7
# Screaming :  7
# Yell :  7
# Female_speech_and_woman_speaking :  7
# Male_speech_and_man_speaking :  7
# Whispering :  7
# Bass_drum :  7
# Hi-hat :  7
# Writing :  7
# Tick-tock :  7
# Hiss :  7
# Crackle :  7
# Church_bell :  7
# Fart :  7
# Male_singing :  7
# Female_singing :  7
# Finger_snapping :  7
# Chewing_and_mastication :  7
# Burping_and_eructation :  7
# Zipper_(clothing) :  7
# Marimba_and_xylophone :  7
# Keys_jangling :  7
# Skateboard :  7
# Computer_keyboard :  7
# Printer :  7
# Gong :  7
# Scissors :  7
#
# 2 :!!!
# Accordion :  4
# Gasp :  4
# Mechanical_fan :  4
# Fill_(with_liquid) :  5
# Sink_(filling_or_washing) :  7
# Water_tap_and_faucet :  7
# Gurgling :  7
# Toilet_flush :  7
# Trickle_and_dribble :  5
# Buzz :  5
# Race_car_and_auto_racing :  5
# Accelerating_and_revving_and_vroom :  7
# Motorcycle :  7
# Glockenspiel :  5
# Sigh :  5
# Frying_(food) :  6
# Traffic_noise_and_roadway_noise :  7
# Sneeze :  6
# Church_bell :  7
# Drip :  7
# Raindrop :  7
# Bathtub_(filling_or_washing) :  7
# Meow :  7
# Purr :  6
# Bicycle_bell :  6
# Applause :  7
# Crowd :  7
# Cheering :  7
# Clapping :  7
# Cutlery_and_silverware :  7
# Dishes_and_pots_and_pans :  7
# Chink_and_clink :  7
# Tap :  7
# Drawer_open_or_close :  7
# Car_passing_by :  7
# Squeak :  7
# Slam :  7
# Cupboard_open_or_close :  7
# Walk_and_footsteps :  7
# Knock :  7
# Bus :  7
# Run :  7
# Microwave_oven :  7
# Chirp_and_tweet :  7
# Cricket :  7
# Bark :  7
# Stream :  7
# Waves_and_surf :  7
# Electric_guitar :  7
# Bass_guitar :  7
# Bass_drum :  7
# Acoustic_guitar :  7
# Strum :  7
# Screaming :  7
# Yell :  7
# Female_speech_and_woman_speaking :  7
# Male_speech_and_man_speaking :  7
# Whispering :  7
# Hi-hat :  7
# Child_speech_and_kid_speaking :  7
# Shatter :  7
# Writing :  7
# Tick-tock :  7
# Hiss :  7
# Crackle :  7
# Harmonica :  7
# Fart :  7
# Female_singing :  7
# Male_singing :  7
# Finger_snapping :  7
# Chewing_and_mastication :  7
# Burping_and_eructation :  7
# Zipper_(clothing) :  7
# Marimba_and_xylophone :  7
# Keys_jangling :  7
# Skateboard :  7
# Computer_keyboard :  7
# Printer :  7
# Gong :  7
# Scissors :  7

# %%
for s in S:
    random.shuffle(s)
file_names = ['train_curated_small.csv', 'val_curated.csv', 'test_curated.csv']
train_set = S[0]
val_set = S[1]
test_set = S[2]

# %%
for idx, file_name in enumerate(file_names):
    with open('../input/' + file_name, 'w+') as f:
        f.write('fname,labels\n')
        for x in S[idx]:
            f.write(x[0] + ',' + ','.join(x[1]) + '\n')
